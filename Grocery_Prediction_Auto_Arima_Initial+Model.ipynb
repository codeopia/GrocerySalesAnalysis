# %%
import pandas as pd
import numpy as np
import datetime

from pyspark.sql import  SparkSession
from pyspark import SparkContext
from pyspark.sql.types import *
from pyspark import SQLContext
import matplotlib.pyplot as plt

from pyspark.sql.functions import col, countDistinct
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql.functions import year, month, dayofmonth

import matplotlib as plot
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# TIME SERIES
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.stattools import adfuller, acf, pacf,arma_order_select_ic
# Out:
# /usr/local/anaconda/python2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## 1. Time Series Analysis - ARIMA

# %%
sc = SparkContext()
sqlContext = SQLContext(sc)

# %%
transaction_data = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/transactions_store44.csv",header = True,inferSchema = True)

# %%
stores_data=sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/stores.csv",header = True,inferSchema = True)

# %%
sales_df =pd.merge(transaction_data.toPandas(),stores_data.toPandas(),how='left')
sales_df.describe()
# Out:
#        store_nbr  transactions  cluster
# count     1089.0   1089.000000   1089.0
# mean        44.0   4325.125803      5.0
# std          0.0    749.300106      0.0
# min         44.0   2333.000000      5.0
# 25%         44.0   3797.000000      5.0
# 50%         44.0   4133.000000      5.0
# 75%         44.0   4787.000000      5.0
# max         44.0   8359.000000      5.0

# %%
sales_df.head()
# Out:
#         date  store_nbr  transactions   city      state type  cluster
# 0 2013-01-02         44          4821  Quito  Pichincha    A        5
# 1 2013-01-03         44          3618  Quito  Pichincha    A        5
# 2 2013-01-04         44          4169  Quito  Pichincha    A        5
# 3 2013-01-05         44          4921  Quito  Pichincha    A        5
# 4 2013-01-06         44          4925  Quito  Pichincha    A        5

# %%
holiday_data = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/holidays_events_2013_2015.csv",header = True,inferSchema = True)
holiday_data_df = holiday_data.toPandas()

# %%
holiday_data_df['date'] = pd.to_datetime(holiday_data_df['date'], format='%b %d, %Y')
sales_df['date'] = pd.to_datetime(sales_df['date'], format='%b %d, %Y')

# %%
# Isolating events that do not correspond to holidays
events=holiday_data_df.loc[holiday_data_df.type=='Event']
holiday_data_df=holiday_data_df.loc[holiday_data_df.type!='Event']

# %%
# Adjuusting this variable to show all holidays
sales_df['year'],sales_df['week'],sales_df['day']=list(zip(*sales_df.date.apply(lambda x: x.isocalendar())))

# Creating a categorical variable showing weekends
sales_df['dayoff']=[x in [6,7] for x in sales_df.day]

# Adjuusting this variable to show all holidays
for (d,t,l,n) in zip(holiday_data_df.date,holiday_data_df.type,holiday_data_df.locale,holiday_data_df.locale_name):
  if t!='Work Day':
    if l=='National':
      sales_df.loc[sales_df.date==d,'dayoff']=True
    elif l=='Regional':
      sales_df.loc[(sales_df.date==d)&(sales_df.state==n),'dayoff']=True
    else:
      sales_df.loc[(sales_df.date==d)&(sales_df.city==n),'dayoff']=True
  else:
    sales_df.loc[(sales_df.date==d),'dayoff']=False

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1089 entries, 0 to 1088
# Data columns (total 11 columns):
# date            1089 non-null datetime64[ns]
# store_nbr       1089 non-null int64
# transactions    1089 non-null int64
# city            1089 non-null object
# state           1089 non-null object
# type            1089 non-null object
# cluster         1089 non-null int64
# year            1089 non-null int64
# week            1089 non-null int64
# day             1089 non-null int64
# dayoff          1089 non-null bool
# dtypes: bool(1), datetime64[ns](1), int64(6), object(3)
# memory usage: 94.6+ KB

# %%
holiday_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 169
# Data columns (total 6 columns):
# date           149 non-null datetime64[ns]
# type           149 non-null object
# locale         149 non-null object
# locale_name    149 non-null object
# description    149 non-null object
# transferred    149 non-null bool
# dtypes: bool(1), datetime64[ns](1), object(4)
# memory usage: 7.1+ KB

# %%
sales_df.head()
# Out:
#         date  store_nbr  transactions   city      state type  cluster  year  \
# 0 2013-01-02         44          4821  Quito  Pichincha    A        5  2013
# 1 2013-01-03         44          3618  Quito  Pichincha    A        5  2013
# 2 2013-01-04         44          4169  Quito  Pichincha    A        5  2013
# 3 2013-01-05         44          4921  Quito  Pichincha    A        5  2013
# 4 2013-01-06         44          4925  Quito  Pichincha    A        5  2013
#
#    week  day  dayoff
# 0     1    3   False
# 1     1    4   False
# 2     1    5   False
# 3     1    6   False
# 4     1    7    True

# %%
sales_df.count()
# Out:
# date            1089
# store_nbr       1089
# transactions    1089
# city            1089
# state           1089
# type            1089
# cluster         1089
# year            1089
# week            1089
# day             1089
# dayoff          1089
# dtype: int64

# %% [markdown]
# ### Time series analysis on Store #44

# %%
train_data = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/train_store44_with_items.csv",header = True,inferSchema = True)

# %%
# Total records should match 
ts=sales_df.loc[sales_df['store_nbr']==44,['date','transactions']].set_index('date')
ts.count()
ts=ts.transactions.astype('float')

# %%
plt.figure(figsize=(8,8))
plt.title('Daily transactions in store #44')
plt.xlabel('time')
plt.ylabel('Number of transactions')
plt.plot(ts);

# %% [markdown]
# #### There are several peaks just before every year end. We can attribute this to the seasonality. The sales will surge during Year and and christmas.

# %%
def dickey_fuller_test(timeseries):
    dickey_fuller_test = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dickey_fuller_test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dickey_fuller_test[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
dickey_fuller_test(ts)
# Out:
# Test Statistic                   -4.013363
# p-value                           0.001342
# #Lags Used                       22.000000
# Number of Observations Used    1066.000000
# Critical Value (5%)              -2.864255
# Critical Value (1%)              -3.436499
# Critical Value (10%)             -2.568216
# dtype: float64

# %% [markdown]
# #### The Time Series can be classified in to Stationary or Non Stationary. Time series are stationary if they do not have trend or seasonal effects. Summary statistics calculated on the time series are consistent over time, like the mean or the variance of the observations.
# #### The Dickey-Fuller test has null-hypothesis that the time-series is non stationary. On our case the P value is less than 0.05. Hence we can reject the null hypothoesis and consider the time series as Stationary.

# %% [markdown]
# ### ARIMA Model for Timeseries

# %% [markdown]
# ARIMA stands for AutoRegressive Integrated Moving Average.The ARIMA models have three parameters, corresponging to its AR, I and MA components:
#
# 1. The number of autoregressive (AR) terms (p): AR terms are just lags of the dependent variable.
# 2. The number of differences (d): These are the number of non-seasonal differences.
# 3. The number of moving average (MA) terms (q): MA terms are lagged forecast errors in the prediction equation.

# %%
plt.figure(figsize=(12,6))
autocorrelation_plot(ts);

# %% [markdown]
# #### The above plot shows that the peaks are attained once every 365 days. That sums up the seasonality.

# %%
plt.figure(figsize=(12,6))
autocorrelation_plot(ts);
plt.xlim(xmax=100);

# %% [markdown]
# #### If we limit this to 100 days, there are total of 14 spikes. Roughly once every 7 days. That also answers the trend that the Ecudorians follow weekly purchases mode.

# %%
plt.figure(figsize=(12,6))
autocorrelation_plot(ts);
plt.xlim(xmax=10);

# %% [markdown]
# #### This is further confirmed by the 10 days plot. where there is a spike at 7th day.

# %% [markdown]
# #### In the below code, a graph is ploted between the log time series and the moving average of  days.

# %%
plt.figure(figsize=(12,6))
ts_log = np.log(ts)
moving_avg = pd.rolling_mean(ts_log,8)
plt.plot(ts_log)
plt.plot(moving_avg, color='red')
# Out:
# /usr/local/anaconda/python2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=8,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# The moving average difference between the original time series and the moving average of 8 days is calculated.
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.head(10)
# Out:
# date
# 2013-01-02         NaN
# 2013-01-03         NaN
# 2013-01-04         NaN
# 2013-01-05         NaN
# 2013-01-06         NaN
# 2013-01-07         NaN
# 2013-01-08         NaN
# 2013-01-09   -0.049045
# 2013-01-10   -0.189456
# 2013-01-11   -0.044809
# Name: transactions, dtype: float64

# %%
# The DF Test is applied on the moving average time series after dropping the NAN data to check the stationality
ts_log_moving_avg_diff.dropna(inplace=True)
dickey_fuller_test(ts_log_moving_avg_diff)
# Out:
# Test Statistic                -7.937679e+00
# p-value                        3.379080e-12
# #Lags Used                     2.200000e+01
# Number of Observations Used    1.059000e+03
# Critical Value (5%)           -2.864273e+00
# Critical Value (1%)           -3.436540e+00
# Critical Value (10%)          -2.568225e+00
# dtype: float64

# %% [markdown]
# #### This looks like a much better series. The rolling values appear to be varying slightly but there is no specific trend. Also, the test statistic is smaller than the 5% critical values so we can say with 95% confidence that this is a stationary series.

# %%
#### Let us plot the timeseries with decomposition data. I.e. Trend, Seasonal and Residual. The frequency is for 365 days.
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log.values, freq=365)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(12,6))
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')

# %% [markdown]
# #### It is observed that over a year data, there is a definite trend in the sales. The seasonality is also well explained here as per our expection.

# %%
#### Let us plot the timeseries with decomposition data. I.e. Trend, Seasonal and Residual. The frequency is for 30 days.
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log.values, freq=30)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(12,6))
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')

# %% [markdown]
# #### Over 30 days, if we observe correctly, there are six spikes approx between 200 days, so that also confirms our analysis.

# %%
### Applying ARIMA with the pdq values 5,0,5 and check the residuals
pdq=(5,0,5)
model = ARIMA(ts_log, order = pdq, freq='W')  
results_AR = model.fit(disp=False,method='css',maxiter=100) 
residuals = pd.DataFrame(results_AR.resid)
residuals.head()
# Out:
#                    0
# date
# 2013-01-07 -0.381552
# 2013-01-08 -0.357352
# 2013-01-09  0.117899
# 2013-01-10  0.026263
# 2013-01-11  0.055091

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(16,8))
residuals.plot(ax=axes[0])
residuals.plot(kind='kde',ax=axes[1]);
residuals.describe().T
# Out:
#     count      mean      std       min       25%       50%       75%       max
# 0  1084.0 -0.000005  0.08955 -0.477191 -0.047955  0.003344  0.047386  0.408671

# %%
results_AR.fittedvalues.head()
# Out:
# date
# 2013-01-07    8.642820
# 2013-01-08    8.544095
# 2013-01-09    8.177649
# 2013-01-10    8.082361
# 2013-01-11    8.206693
# dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot
plt.plot(ts_log);
plt.plot(results_AR.fittedvalues,alpha=.7);

# %% [markdown]
# #### The model does fit well. But we can see that some part of the outliers are fitted.

# %%
ts.index
# Out:
# DatetimeIndex(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-05',
#                '2013-01-06', '2013-01-07', '2013-01-08', '2013-01-09',
#                '2013-01-10', '2013-01-11',
#                ...
#                '2015-12-21', '2015-12-22', '2015-12-23', '2015-12-24',
#                '2015-12-26', '2015-12-27', '2015-12-28', '2015-12-29',
#                '2015-12-30', '2015-12-31'],
#               dtype='datetime64[ns]', name=u'date', length=1089, freq=None)

# %%
####
from pyramid.arima import auto_arima
stepwise_model = auto_arima(ts, start_p=1, start_q=1,
                           max_p=7, max_q=7, m=12,
                           start_P=0, max_P=7, seasonal=True,
                           d=0, D=0,
                           trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=16911.866, BIC=16936.831, Fit time=2.030 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 0, 0, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 0, 0, 12); AIC=16959.238, BIC=16979.210, Fit time=2.636 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 1, 12); AIC=16964.070, BIC=16984.043, Fit time=2.150 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 0, 1, 12); AIC=16921.876, BIC=16951.834, Fit time=4.116 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 0, 12); AIC=17004.015, BIC=17023.987, Fit time=0.467 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=16909.802, BIC=16939.760, Fit time=6.202 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=16966.348, BIC=16991.313, Fit time=5.013 seconds
# Fit ARIMA: order=(2, 0, 1) seasonal_order=(0, 0, 2, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(0, 0, 2, 12); AIC=16984.034, BIC=17008.999, Fit time=3.127 seconds
# Fit ARIMA: order=(1, 0, 2) seasonal_order=(0, 0, 2, 12); AIC=16889.767, BIC=16924.718, Fit time=5.127 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 2, 12); AIC=16868.228, BIC=16913.166, Fit time=16.168 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(1, 0, 2, 12); AIC=nan, BIC=nan, Fit time=3.423 seconds
# Fit ARIMA: order=(2, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=16866.216, BIC=16906.160, Fit time=6.612 seconds
# Fit ARIMA: order=(1, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=16877.102, BIC=16912.054, Fit time=3.035 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 1, 12); AIC=16788.216, BIC=16833.154, Fit time=6.108 seconds
# Fit ARIMA: order=(3, 0, 2) seasonal_order=(0, 0, 1, 12); AIC=16803.216, BIC=16843.160, Fit time=6.009 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 1, 12); AIC=16780.232, BIC=16830.162, Fit time=6.591 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=nan, BIC=nan, Fit time=0.817 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(1, 0, 1, 12); AIC=17165.535, BIC=17220.458, Fit time=11.756 seconds
# Fit ARIMA: order=(3, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=16669.993, BIC=16714.930, Fit time=2.395 seconds
# Fit ARIMA: order=(2, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=16873.647, BIC=16913.591, Fit time=2.202 seconds
# Fit ARIMA: order=(4, 0, 4) seasonal_order=(0, 0, 0, 12); AIC=nan, BIC=nan, Fit time=0.404 seconds
# Fit ARIMA: order=(3, 0, 3) seasonal_order=(0, 0, 0, 12); AIC=16846.991, BIC=16886.935, Fit time=1.843 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=16601.363, BIC=16651.293, Fit time=3.495 seconds
# Fit ARIMA: order=(4, 0, 6) seasonal_order=(0, 0, 0, 12); AIC=nan, BIC=nan, Fit time=0.495 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 0, 12); AIC=17363.909, BIC=17418.833, Fit time=10.720 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(0, 0, 1, 12); AIC=16602.455, BIC=16657.378, Fit time=9.371 seconds
# Fit ARIMA: order=(3, 0, 5) seasonal_order=(1, 0, 1, 12); AIC=16999.296, BIC=17059.212, Fit time=13.736 seconds
# Fit ARIMA: order=(2, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=16908.268, BIC=16953.205, Fit time=1.846 seconds
# Fit ARIMA: order=(4, 0, 5) seasonal_order=(0, 0, 0, 12); AIC=nan, BIC=nan, Fit time=0.426 seconds
# Fit ARIMA: order=(3, 0, 6) seasonal_order=(0, 0, 0, 12); AIC=16654.824, BIC=16709.747, Fit time=3.401 seconds
# Total fit time: 141.749 seconds
# 16780.232119032247

# %%
stepwise_model.aic()
# Out:
# 16780.232119032247

# %%
#forecast_len = 90
#size = int(len(ts_log)-forecast_len)
#train, test = ts_log[0:size], ts_log[size:len(ts_log)]
index = pd.date_range('2016-01-01', periods=31)
train  = ts_log
#columns = ['sales']
#test = pd.DataFrame(index=index, columns=columns)

# %%
fit_model = stepwise_model.fit(train)
fit_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 1089
# Model:             SARIMAX(3, 0, 4)x(0, 0, 1, 12)   Log Likelihood                 749.689
# Date:                            Mon, 30 Jul 2018   AIC                          -1479.378
# Time:                                    06:25:18   BIC                          -1429.448
# Sample:                                         0   HQIC                         -1460.480
#                                            - 1089
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      2.7758      1.178      2.356      0.018       0.467       5.085
# ar.L1          0.9748      0.129      7.542      0.000       0.721       1.228
# ar.L2         -0.8212      0.076    -10.834      0.000      -0.970      -0.673
# ar.L3          0.5141      0.067      7.681      0.000       0.383       0.645
# ma.L1         -0.3084      0.139     -2.216      0.027      -0.581      -0.036
# ma.L2          0.4782      0.070      6.828      0.000       0.341       0.616
# ma.L3          0.1569      0.078      2.022      0.043       0.005       0.309
# ma.L4         -0.3564      0.085     -4.189      0.000      -0.523      -0.190
# ma.S.L12      -0.2628      0.038     -6.928      0.000      -0.337      -0.188
# sigma2         0.0152      0.001     19.702      0.000       0.014       0.017
# ===================================================================================
# Ljung-Box (Q):                     1544.48   Jarque-Bera (JB):                 4.87
# Prob(Q):                              0.00   Prob(JB):                         0.09
# Heteroskedasticity (H):               0.98   Skew:                            -0.16
# Prob(H) (two-sided):                  0.83   Kurtosis:                         3.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
predict = np.exp(fit_model.predict(31))
predict
# Out:
# array([4845.35061995, 4422.89279467, 3792.77116015, 3707.61509434,
#        3799.06817217, 3833.74998868, 3951.97081245, 4092.9414718 ,
#        4231.54928241, 4097.14346963, 3854.24125328, 3867.8041886 ,
#        3960.52904035, 4110.59328818, 4243.88079717, 4213.38148913,
#        4145.42764863, 4172.36511524, 4239.48255722, 4247.45522081,
#        4213.84969499, 4209.2903975 , 4236.45805044, 4249.51351571,
#        4237.46159065, 4229.04565075, 4237.4105654 , 4246.31330947,
#        4243.77162557, 4238.29503996, 4239.61667952])

# %%
future_forecast = pd.DataFrame(predict,index = index,columns=['Prediction'])
future_forecast.head(5)
# Out:
#              Prediction
# 2016-01-01  4845.350620
# 2016-01-02  4422.892795
# 2016-01-03  3792.771160
# 2016-01-04  3707.615094
# 2016-01-05  3799.068172

# %%
pd.concat([np.exp(train),future_forecast],axis=1).plot()

# %%
full_transaction_data = sqlContext.read.csv("/gl-capstone-data/Team6-C-Sep/Data/transactions.csv",header = True,inferSchema = True)
full_transaction_data.head()
# Out:
# Row(date=datetime.datetime(2013, 1, 1, 0, 0), store_nbr=25, transactions=770)

# %%
jan_2016_data =  full_transaction_data.filter(col('store_nbr') == 44).filter(year(col('date')) == 2016).filter(month(col('date')) == 1)
jan_2016_data_pd = jan_2016_data.toPandas()

# %%
jan_2016_data_pd.head()
# Out:
#         date  store_nbr  transactions
# 0 2016-01-02         44          4539
# 1 2016-01-05         44          4113
# 2 2016-01-06         44          4661
# 3 2016-01-07         44          3866
# 4 2016-01-08         44          4301

# %%
jan_2016_data_pd = jan_2016_data_pd.drop(['store_nbr'], axis=1)
jan_2016_data_pd.set_index('date')
jan_2016_data_pd.head()
# Out:
#         date  transactions
# 0 2016-01-02          4539
# 1 2016-01-05          4113
# 2 2016-01-06          4661
# 3 2016-01-07          3866
# 4 2016-01-08          4301

# %%
sum_trans =  full_transaction_data.filter(col('store_nbr') == 44).groupby(year('date'), month('date')).sum()
sum_trans.filter(col('year(date)') == 2016).filter(col('month(date)') == 1).show()
# Out:
# +----------+-----------+--------------+-----------------+
# |year(date)|month(date)|sum(store_nbr)|sum(transactions)|
# +----------+-----------+--------------+-----------------+
# |      2016|          1|          1232|           120720|
# +----------+-----------+--------------+-----------------+

# %%
sum(future_forecast['Prediction'])
# Out:
# 128411.2395848327

# %%
future_forecast.index
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10', '2016-01-11', '2016-01-12',
#                '2016-01-13', '2016-01-14', '2016-01-15', '2016-01-16',
#                '2016-01-17', '2016-01-18', '2016-01-19', '2016-01-20',
#                '2016-01-21', '2016-01-22', '2016-01-23', '2016-01-24',
#                '2016-01-25', '2016-01-26', '2016-01-27', '2016-01-28',
#                '2016-01-29', '2016-01-30', '2016-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
jan_2016_data_pd['date'] = pd.to_datetime(jan_2016_data_pd['date'], format='%b %d, %Y')
jan_2016_data_pd.index = pd.to_datetime(jan_2016_data_pd['date'])
jan_2016_data_pd.columns = ['date', 'actuals']
jan_2016_data_pd.index
# Out:
# DatetimeIndex(['2016-01-02', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-09', '2016-01-10', '2016-01-11',
#                '2016-01-12', '2016-01-13', '2016-01-14', '2016-01-15',
#                '2016-01-16', '2016-01-17', '2016-01-18', '2016-01-19',
#                '2016-01-20', '2016-01-21', '2016-01-22', '2016-01-23',
#                '2016-01-24', '2016-01-25', '2016-01-26', '2016-01-27',
#                '2016-01-28', '2016-01-29', '2016-01-30', '2016-01-31'],
#               dtype='datetime64[ns]', name=u'date', freq=None)

# %%
merged = future_forecast.merge(jan_2016_data_pd, left_index=True, right_index=True, how='inner')
merged.drop('date', axis = 1)
# Out:
#              Prediction  actuals
# 2016-01-02  4422.892795     4539
# 2016-01-05  3799.068172     4113
# 2016-01-06  3833.749989     4661
# 2016-01-07  3951.970812     3866
# 2016-01-08  4092.941472     4301
# 2016-01-09  4231.549282     5186
# 2016-01-10  4097.143470     5220
# 2016-01-11  3854.241253     3968
# 2016-01-12  3867.804189     3743
# 2016-01-13  3960.529040     3956
# 2016-01-14  4110.593288     3784
# 2016-01-15  4243.880797     4416
# 2016-01-16  4213.381489     5207
# 2016-01-17  4145.427649     5009
# 2016-01-18  4172.365115     4025
# 2016-01-19  4239.482557     3844
# 2016-01-20  4247.455221     4337
# 2016-01-21  4213.849695     3534
# 2016-01-22  4209.290398     4195
# 2016-01-23  4236.458050     4982
# 2016-01-24  4249.513516     4766
# 2016-01-25  4237.461591     3773
# 2016-01-26  4229.045651     3618
# 2016-01-27  4237.410565     3986
# 2016-01-28  4246.313309     3669
# 2016-01-29  4243.771626     4072
# 2016-01-30  4238.295040     5043
# 2016-01-31  4239.616680     4907

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(merged['actuals'], merged['Prediction'])
# Out:
# 303424.54287966184

# %%
merged.plot()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-93-c681a60962fd> in <module>()
# ----> 1 merged.plot()
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
# -> 1729     plot_obj.generate()
#    1730     plot_obj.draw()
#    1731     return plot_obj.result
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in generate(self)
#     256
#     257         for ax in self.axes:
# --> 258             self._post_plot_logic_common(ax, self.data)
#     259             self._post_plot_logic(ax, self.data)
#     260
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _post_plot_logic_common(self, ax, data)
#     395             self._apply_axis_properties(ax.xaxis, rot=self.rot,
#     396                                         fontsize=self.fontsize)
# --> 397             self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     398
#     399             if hasattr(ax, 'right_ax'):
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/pandas/plotting/_core.pyc in _apply_axis_properties(self, axis, rot, fontsize)
#     468
#     469     def _apply_axis_properties(self, axis, rot=None, fontsize=None):
# --> 470         labels = axis.get_majorticklabels() + axis.get_minorticklabels()
#     471         for label in labels:
#     472             if rot is not None:
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/axis.pyc in get_majorticklabels(self)
#    1186     def get_majorticklabels(self):
#    1187         'Return a list of Text instances for the major ticklabels'
# -> 1188         ticks = self.get_major_ticks()
#    1189         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1190         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/axis.pyc in get_major_ticks(self, numticks)
#    1337         'get the tick instances; grow as necessary'
#    1338         if numticks is None:
# -> 1339             numticks = len(self.get_major_locator()())
#    1340         if len(self.majorTicks) < numticks:
#    1341             # update the new tick label properties from the old
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in __call__(self)
#    1052     def __call__(self):
#    1053         'Return the locations of the ticks'
# -> 1054         self.refresh()
#    1055         return self._locator()
#    1056
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in refresh(self)
#    1072     def refresh(self):
#    1073         'Refresh internal information based on current limits.'
# -> 1074         dmin, dmax = self.viewlim_to_dt()
#    1075         self._locator = self.get_locator(dmin, dmax)
#    1076
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in viewlim_to_dt(self)
#     830             vmin, vmax = vmax, vmin
#     831
# --> 832         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#     833
#     834     def _get_unit(self):
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in num2date(x, tz)
#     439         tz = _get_rc_timezone()
#     440     if not cbook.iterable(x):
# --> 441         return _from_ordinalf(x, tz)
#     442     else:
#     443         x = np.asarray(x)
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in _from_ordinalf(x, tz)
#     254
#     255     ix = int(x)
# --> 256     dt = datetime.datetime.fromordinal(ix).replace(tzinfo=UTC)
#     257
#     258     remainder = float(x) - ix
#
# ValueError: ordinal must be >= 1
# ValueErrorTraceback (most recent call last)
# /usr/local/anaconda/python2/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     238
#     239     if 'png' in formats:
# --> 240         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     241     if 'retina' in formats or 'png2x' in formats:
#     242         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     122
#     123     bytes_io = BytesIO()
# --> 124     fig.canvas.print_figure(bytes_io, **kw)
#     125     data = bytes_io.getvalue()
#     126     if fmt == 'svg':
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2206                     orientation=orientation,
#    2207                     dryrun=True,
# -> 2208                     **kwargs)
#    2209                 renderer = self.figure._cachedRenderer
#    2210                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     505
#     506     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 507         FigureCanvasAgg.draw(self)
#     508         renderer = self.get_renderer()
#     509         original_dpi = renderer.dpi
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     428             if toolbar:
#     429                 toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             if toolbar:
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1293
#    1294             mimage._draw_list_compositing_images(
# -> 1295                 renderer, self, artists, self.suppressComposite)
#    1296
#    1297             renderer.close_group('figure')
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2397             renderer.stop_rasterizing()
#    2398
# -> 2399         mimage._draw_list_compositing_images(renderer, self, artists)
#    2400
#    2401         renderer.close_group('axes')
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1131         renderer.open_group(__name__)
#    1132
# -> 1133         ticks_to_draw = self._update_ticks(renderer)
#    1134         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1135                                                                 renderer)
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/axis.pyc in _update_ticks(self, renderer)
#     972
#     973         interval = self.get_view_interval()
# --> 974         tick_tups = list(self.iter_ticks())
#     975         if self._smart_bounds and tick_tups:
#     976             # handle inverted limits
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/axis.pyc in iter_ticks(self)
#     915         Iterate through all of the major and minor ticks.
#     916         """
# --> 917         majorLocs = self.major.locator()
#     918         majorTicks = self.get_major_ticks(len(majorLocs))
#     919         self.major.formatter.set_locs(majorLocs)
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in __call__(self)
#    1052     def __call__(self):
#    1053         'Return the locations of the ticks'
# -> 1054         self.refresh()
#    1055         return self._locator()
#    1056
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in refresh(self)
#    1072     def refresh(self):
#    1073         'Refresh internal information based on current limits.'
# -> 1074         dmin, dmax = self.viewlim_to_dt()
#    1075         self._locator = self.get_locator(dmin, dmax)
#    1076
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in viewlim_to_dt(self)
#     830             vmin, vmax = vmax, vmin
#     831
# --> 832         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#     833
#     834     def _get_unit(self):
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in num2date(x, tz)
#     439         tz = _get_rc_timezone()
#     440     if not cbook.iterable(x):
# --> 441         return _from_ordinalf(x, tz)
#     442     else:
#     443         x = np.asarray(x)
#
# /usr/local/anaconda/python2/lib/python2.7/site-packages/matplotlib/dates.pyc in _from_ordinalf(x, tz)
#     254
#     255     ix = int(x)
# --> 256     dt = datetime.datetime.fromordinal(ix).replace(tzinfo=UTC)
#     257
#     258     remainder = float(x) - ix
#
# ValueError: ordinal must be >= 1

# %% [markdown]
# ### Inference:
# The total number of transactions reqported out of the model is 135006 and the actual number of transactions from the data for the month of Jan 2016 is 120720

# %% [markdown]
# ## 2. Sulekha-Holtwinters implementation
